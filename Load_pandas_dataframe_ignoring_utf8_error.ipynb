# %% [markdown]
# <a href="https://colab.research.google.com/github/sayan0506/Reference-studies/blob/main/Load_pandas_dataframe_ignoring_utf8_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Reference: https://stackoverflow.com/questions/18357675/unicodedecodeerror-unexpected-end-of-data

# %%
fileName = "/content/drive/MyDrive/Cityscape Dataset/2013-boston-marathon-bombing.csv"
with open(fileName, encoding="utf-8",errors='ignore') as infile:
  df = pd.read_csv(infile)

# %%
df
# Out:
#         coordinates  ... verified
# 0               NaN  ...    False
# 1               NaN  ...    False
# 2               NaN  ...    False
# 3               NaN  ...    False
# 4               NaN  ...    False
# ...             ...  ...      ...
# 1048570         NaN  ...    False
# 1048571         NaN  ...    False
# 1048572         NaN  ...    False
# 1048573         NaN  ...    False
# 1048574         NaN  ...    False
#
# [1048575 rows x 34 columns]
